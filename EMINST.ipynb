# %%
#Install EMIST library, import datasets of letters, Matplotlib
pip install emnist
from emnist import list_datasets
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# Collecting emnistNote: you may need to restart the kernel to use updated packages.
#
#   Downloading emnist-0.0-py3-none-any.whl (7.3 kB)
# Requirement already satisfied: tqdm in c:\users\gchandr4\anaconda3\lib\site-packages (from emnist) (4.50.2)
# Requirement already satisfied: requests in c:\users\gchandr4\anaconda3\lib\site-packages (from emnist) (2.24.0)
# Requirement already satisfied: numpy in c:\users\gchandr4\anaconda3\lib\site-packages (from emnist) (1.19.2)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\gchandr4\anaconda3\lib\site-packages (from requests->emnist) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\gchandr4\anaconda3\lib\site-packages (from requests->emnist) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\gchandr4\anaconda3\lib\site-packages (from requests->emnist) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\gchandr4\anaconda3\lib\site-packages (from requests->emnist) (2020.6.20)
# Installing collected packages: emnist
# Successfully installed emnist-0.0

# %%
#Download dataset and it is 536 MB
list_datasets()
# Out:
# Downloading emnist.zip: 536MB [03:19, 2.82MB/s]
# ['balanced', 'byclass', 'bymerge', 'digits', 'letters', 'mnist']

# %%
#Download images of letters from training samples or test samples
#from emnist import extract_test_samples
from emnist import extract_training_samples
images, labels = extract_training_samples('letters')
images.shape
# Out:
# (124800, 28, 28)

# %%
#Let's print first letters from EMINST training samples
sample_letter = images[0]
sample_letter_resize = sample_letter.reshape(28, 28)
plt.imshow(sample_letter_resize, cmap = 'binary')
plt.axis("off")
plt.show()

# %%
#Let's print first 10 letters from EMINST training samples
for i in range(10):
    first_ten_letters = images[i].reshape((28, 28))
    plt.imshow(first_ten_letters, cmap = 'binary')
    #plt.axis("off")
    plt.show()
